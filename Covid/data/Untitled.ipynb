# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('covid.csv')
df1 = df[['Age', 'Sex', 'DateRepConf', 'Location', 'Latitude','Longitude','Island Group']]
# Out:
#         Age     Sex DateRepConf                        Location   Latitude  \
# 0      53.0  Female    11-05-20          San Pedro City, Laguna  14.352675
# 1      31.0    Male    12-04-20    Parañaque City, Metro Manila  14.479309
# 2      33.0  Female    19-05-20                             NaN  14.615870
# 3      58.0    Male    29-03-20  Mandaluyong City, Metro Manila  14.579526
# 4      35.0    Male    21-05-20                   Cebu Province  10.326339
# ...     ...     ...         ...                             ...        ...
# 13429  54.0  Female    27-04-20  Mandaluyong City, Metro Manila  14.579526
# 13430  38.0    Male    29-04-20                             NaN  14.615870
# 13431  50.0  Female    13-04-20  Mandaluyong City, Metro Manila  14.579526
# 13432  87.0    Male    12-05-20                    Metro Manila  14.615867
# 13433  52.0    Male    12-05-20             Bacoor City, Cavite  14.412934
#
#         Longitude Island Group
# 0      121.045340        Luzon
# ...

# %%
ax = plt.hist(df['Age'], bins=20)
